# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/placement.csv')
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df=df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
import matplotlib.pyplot as plt

# %%
scatterplot=plt.scatter(df['cgpa'],df['iq'],c=df['placement'])
plt.xlabel('CGPA')
plt.ylabel('IQ')
plt.show()

# %%
X=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)   #10% is test data and 90 is training

# %%
X_train
# X_test
# y_train
# y_test
# Out:
#     cgpa     iq
# 72   7.3  116.0
# 56   6.1   65.0
# 48   6.6  138.0
# 92   5.2  110.0
# 5    7.1   48.0
# ..   ...    ...
# 73   4.9   61.0
# 61   7.3  137.0
# 22   4.9  120.0
# 52   7.0  175.0
# 40   4.9  134.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 72    1
# 56    0
# 48    1
# 92    0
# 5     1
#      ..
# 73    0
# 61    1
# 22    0
# 52    1
# 40    0
# Name: placement, Length: 90, dtype: int64

# %%
X_test
# Out:
#     cgpa     iq
# 86   5.1  128.0
# 47   5.2  161.0
# 6    5.7  143.0
# 41   5.4  114.0
# 21   7.1  151.0
# 44   7.5   61.0
# 19   5.2  132.0
# 58   8.0   79.0
# 7    5.0   63.0
# 78   6.1   81.0

# %%
y_test
# Out:
# 86    0
# 47    0
# 6     0
# 41    0
# 21    1
# 44    1
# 19    0
# 58    1
# 7     0
# 78    0
# Name: placement, dtype: int64

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.1447299 , -0.22385007],
#        [ 0.0987838 , -1.5002126 ],
#        [ 0.53459467,  0.32673768],
#        [-0.68567578, -0.37401037],
#        [ 0.97040555, -1.92566677],
#        [ 0.53459467, -0.12374321],
#        [-0.9471623 ,  0.75219186],
#        [-0.16270273,  1.02748574],
#        [-1.12148665, -0.09871649],
#        [-0.51135143,  0.3517644 ],
#        [-0.9471623 ,  1.77828722],
#        [ 1.40621642,  0.07647052],
#        [-0.9471623 ,  0.65208499],
#        [ 0.4474325 , -0.87454469],
#        [ 0.7960812 ,  0.3517644 ],
#        [ 0.4474325 ,  0.87732544],
#        [ 2.190676  , -0.12374321],
#        [-0.68567578,  2.47903528],
#        [-0.2498649 ,  0.37679112],
#        [-0.16270273,  0.42684455],
#        [-1.20864883,  0.52695141],
#        [ 1.8420273 ,  1.02748574],
#        [ 0.88324337, -0.32395694],
#        [ 0.70891902, -0.04866306],
#        [-1.81878405, -0.39903709],
#        [ 1.31905425,  0.82727201],
#        [ 0.01162162, -0.02363634],
# ...

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.77283795,  0.07647052],
#        [-0.68567578,  0.90235216],
#        [-0.2498649 ,  0.45187126],
#        [-0.51135143, -0.2739035 ],
#        [ 0.97040555,  0.65208499],
#        [ 1.31905425, -1.60031946],
#        [-0.68567578,  0.17657739],
#        [ 1.75486512, -1.14983857],
#        [-0.86000013, -1.55026603],
#        [ 0.0987838 , -1.09978514]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()  #create object for logistic regression

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#model training
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 86    0
# 47    0
# 6     0
# 41    0
# 21    1
# 44    1
# 19    0
# 58    1
# 7     0
# 78    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %% [markdown]
# plotting decision boundary

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
